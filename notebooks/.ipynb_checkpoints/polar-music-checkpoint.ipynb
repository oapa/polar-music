# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn

# %%
music_data = pd.read_csv('../data/processed/moonlight.csv')

# %%
music_data.plot(x='measureNumber', y='frequency', kind='scatter')
